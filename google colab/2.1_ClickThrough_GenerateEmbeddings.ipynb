# %% [markdown]
# # Protein Language Model Embeddings Generator

# %%
#@title 1. Install Required Dependencies
#@markdown Run this cell first to install the necessary packages
# %%capture
# !pip install h5py numpy pandas pyfaidx torch tqdm transformers Bio

# %%
#@title ### 2. Import Libraries and Setup
from pathlib import Path
import h5py
import numpy as np
import pandas as pd
import torch
from pyfaidx import Fasta
from tqdm import tqdm
from transformers import AutoTokenizer, EsmModel, T5EncoderModel, T5Tokenizer
from google.colab import files
import os
from Bio import SeqIO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title ### 3. Select Model and Upload File

#@markdown Choose a protein language model:
model_name = "Rostlab/prot_t5_xl_half_uniref50-enc" #@param ["Rostlab/prot_t5_xl_half_uniref50-enc", "ElnaggarLab/ankh-base", "ElnaggarLab/ankh-large", "facebook/esm2_t6_8M_UR50D", "facebook/esm2_t12_35M_UR50D", "facebook/esm2_t30_150M_UR50D", "facebook/esm2_t33_650M_UR50D"]

#@markdown Choose embedding type:
embedding_type = "per_prot" #@param ["per_prot", "per_res"]

# @markdown Select or upload your FASTA file:
fasta_filename = "/content/drive/MyDrive/gobi/deneme/umapFasta.fna" # @param {type:"string", placeholder:"filepath to FASTA file"}
if not fasta_filename:
    uploaded = files.upload()
    fasta_filename = list(uploaded.keys())[0]

#Hidden helper functions
def seq_preprocess(df, model_type="esm"):
    df["sequence"] = df["sequence"].str.replace("[UZO]", "X", regex=True)
    if model_type == "pt":
        df["sequence"] = df.apply(lambda row: " ".join(row["sequence"]), axis=1)
    return df
#@markdown ---
def setup_model(checkpoint):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    if "esm" in checkpoint:
        mod_type = "esm"
        tokenizer = AutoTokenizer.from_pretrained(checkpoint)
        model = EsmModel.from_pretrained(checkpoint)
    elif "ankh" in checkpoint:
        mod_type = "ankh"
        tokenizer = AutoTokenizer.from_pretrained(checkpoint)
        model = T5EncoderModel.from_pretrained(checkpoint)
    else:
        mod_type = "pt"
        tokenizer = T5Tokenizer.from_pretrained(checkpoint)
        model = T5EncoderModel.from_pretrained(checkpoint, torch_dtype=torch.float16)
        model = model.half()
    return model.to(device), tokenizer, mod_type

def read_fasta(file_path):
    headers = []
    sequences = []
    with open(file_path, "r") as f:
      for record in SeqIO.parse(f, "fasta"):
          headers.append(record.description)
          sequences.append(str(record.seq))

    return headers, sequences

def create_embedding(checkpoint, df, emb_type="per_prot", output_file="protein_embeddings.h5"):
    print("Setting up modeli...")
    model, tokenizer, mod_type = setup_model(checkpoint)
    model.eval()
    df = seq_preprocess(df, mod_type)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def compute_embedding(sequence, emb_type):
        inputs = tokenizer(
            sequence,
            return_tensors="pt",
            max_length=4_000,
            truncation=True,
            padding=True,
            add_special_tokens=True,
        ).to(device)
        with torch.no_grad():
            outputs = model(**inputs).last_hidden_state.cpu().numpy()
        if emb_type == "per_res":
            if mod_type in ["pt", "ankh"]:
                outputs = outputs[:-1, :]
            elif mod_type == "esm":
                outputs = np.squeeze(outputs, axis=0)[:-1, :]
            return outputs
        elif emb_type == "per_prot":
            return outputs.mean(axis=1).flatten()
        else:
            raise ValueError("Input valid embedding type")

    print("Generating embeddings...")
    with h5py.File(output_file, "a") as hdf:
        for _, row in tqdm(df.iterrows(), total=len(df)):
            sequence = row["sequence"]
            header = row["header"]
            if header in hdf:
                continue
            embedding = compute_embedding(sequence, emb_type)
            hdf.create_dataset(name=header, data=embedding)

    del model, tokenizer
    torch.cuda.empty_cache()

# %%
#@title ### 4. Generate Embeddings
#@markdown Click the play button to start generating embeddings

fasta_path = Path(fasta_filename)
output_file = "/content/drive/MyDrive/gobi/deneme/umap.h5"

# Create DataFrame and generate embeddings
headers, sequences = read_fasta(fasta_path)
print(headers)
df = pd.DataFrame({"header": headers, "sequence": sequences})
print(f"Processing {len(df)} sequences...")

create_embedding(
    model_name,
    df,
    emb_type=embedding_type,
    output_file=output_file
)

print(f"\nEmbeddings saved to {output_file}")
# Out:
# ['2_Bombyx_mori|NP_001106733.1 FIBH  [GeneID=693030]', 'Bombyxmandarina|XP_028034730.1 FIBH  [GeneID=114246424]', 'Galleria_mellonella|XP_026760882.2 FIBH  [GeneID=113519866]', '2_Manduca_sexta|XP_037294123.1 FIBH  [GeneID=115449923]', 'Vanessa_cardui|XP_046971272.1 FIBH  [GeneID=124538299] [isoform=X1]', 'Maniola_jurtina|XP_045777009.1 FIBH  [GeneID=123875302]', 'Apis_mellifera|XP_006561846.2 LOC726750  [GeneID=726750] [isoform=X1]', 'Monomorium_pharaonis|XP_012524667.2 LOC105830070  [GeneID=105830070]', 'Homalodisca vitripennis |XP_046671070.1 LOC124361079  [GeneID=124361079]', '2_Planococcus_citri|XP_065218367.1 LOC135844163  [GeneID=135844163]', 'Ischnura_elegans|XP_046382228.1 LOC124153170  [GeneID=124153170]', 'XP_045537968.1 fibroin heavy chain [Papilio machaon]', 'XP_063895925.1 fibroin heavy chain [Helicoverpa armigera]', 'NP_001106733.1 fibroin heavy chain precursor [Bombyx mori]', 'XP_037963315.2 fibroin heavy chain isoform X1 [Plutella xylostella]', 'XP_060805381.1 fibroin heavy chain isoform X1 [Amyelois transitella]', 'Papilio machaon|XP_045537968.1 fibroin heavy chain', 'Helicoverpa armigera|XP_063895925.1 fibroin heavy chain', 'Pieris rapae|XP_022116696.2 fibroin heavy chain-like', 'Danaus plexippus|XP_061384490.1 fibroin heavy chain-like', 'Spodoptera frugiperda|XP_050551604.1 fibroin heavy chain', 'Pararge aegeria|XP_039757906.1 fibroin heavy chain-like', 'Aricia agestis|XP_041969262.1 fibroin heavy chain-like', 'Colias croceus|XP_045502918.1 fibroin heavy chain-like', 'Pieris brassicae|XP_045528484.1 fibroin heavy chain-like', 'Helicoverpa zea|XP_047033624.1 fibroin heavy chain-like', 'Pieris napi|XP_047511311.1 fibroin heavy chain-like', 'Vanessa atalanta|XP_047536805.1 fibroin heavy chain-like', 'Leptidea sinapis|XP_050665953.1 fibroin heavy chain-like isoform X1', 'Plodia interpunctella|XP_053613783.1 fibroin heavy chain', 'Ostrinia nubilalis|XP_063831517.1 fibroin heavy chain-like', 'Battus philenor|XP_068619390.1 fibroin heavy chain-like']
# Processing 32 sequences...
# Setting up modeli...
# Generating embeddings...
#   0%|          | 0/32 [00:00<?, ?it/s]

# %%
#@title ### 5. Download Results
#@markdown Run this cell to download your embeddings file
files.download(output_file)
