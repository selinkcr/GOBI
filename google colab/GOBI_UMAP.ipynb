# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U kaleido hdbscan umap-learn plotly
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.11/dist-packages (0.2.1)
# Requirement already satisfied: hdbscan in /usr/local/lib/python3.11/dist-packages (0.8.40)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.7)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (6.0.1)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.11/dist-packages (from hdbscan) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.11/dist-packages (from hdbscan) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly) (1.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20->hdbscan) (3.6.0)

# %%
# Imports
import h5py
import pandas as pd
import numpy as np
from sklearn.preprocessing import normalize
from umap import UMAP
import hdbscan
import plotly.express as px
import plotly.graph_objs as go

# %%
# Load embeddings from H5 file
h5_file_path = '/content/drive/MyDrive/gobi/deneme/umap.h5'

embeddings_list = []
names_list = []

with h5py.File(h5_file_path, 'r') as h5_file:
    for name in h5_file:
        current_embedding = h5_file[name][:]
        embeddings_list.append(current_embedding)
        names_list.append(name)

# %%
# Taksonomik grupları eşleştir
group_map = {
    'Apis_mellifera': 'Hymenoptera (bee)',
    'Bombyx_mandarina': 'Lepidoptera',
    'Plutella_xylostella': 'Lepidoptera',
    'Galleria_mellonella': 'Lepidoptera',
    'Achroia_grisella': 'Lepidoptera',
    'Manduca_sexta': 'Lepidoptera',
    'Cydia_amplana': 'Lepidoptera',
    'Vanessa_cardui': 'Lepidoptera (butterfly)',
    'Maniola_jurtina': 'Lepidoptera (butterfly)',
    'Bombus_impatiens': 'Hymenoptera (ant)',
    'Monomorium_pharaonis': 'Hymenoptera (ant)',
    'Leptopilina_boulardi': 'Hymenoptera (wasp)',
    'Vespula_vulgaris': 'Hymenoptera (wasp)',
    'Cotesia_glomerata': 'Hymenoptera (wasp)',
    'Nilaparvata_lugens': 'Hemiptera',
    'Homalodisca_vitripennis': 'Hemiptera',
    'Cimex_lectularius': 'Hemiptera (bug)',
    'Halyomorpha_halys': 'Hemiptera (bug)',
    'Ischnura_elegans': 'Outgroup',
    'Planococcus_citri': 'Outgroup',
    'Bombyx mori': 'Lepidoptera'


}
# label sütununda tür adları zaten var
umap_df_2d['Group'] = umap_df_2d['label'].map(group_map)
import plotly.express as px

fig = px.scatter(
    umap_df_2d,
    x='UMAP_1',
    y='UMAP_2',
    color='Group',
    text='label',  # Nokta üstüne tür adını yaz
    title='🧬 UMAP of FibH Embeddings Colored by Taxonomic Group',
    width=1000,
    height=700
)

fig.update_traces(textposition='top center')
fig.update_layout(
    font=dict(size=13),
    title_x=0.5,
    plot_bgcolor='rgba(240,240,240,0.95)'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="30edad60-53f9-40c5-b66c-c72cfff5c948" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("30edad60-53f9-40c5-b66c-c72cfff5c948")) {                    Plotly.newPlot(                        "30edad60-53f9-40c5-b66c-c72cfff5c948",                        [{"hovertemplate":"Group=nan\u003cbr\u003eUMAP_1=%{x}\u003cbr\u003eUMAP_2=%{y}\u003cbr\u003elabel=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"nan","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"nan","orientation":"v","showlegend":true,"text":["Achroia_grisella|XP_059058269.1_LOC131851741__[GeneID=131851741]","Apis_mellifera|XP_006561846.2_LOC726750__[GeneID=726750]_[isoform=X1]","Bombus_impatiens|XP_012244504.1_LOC105681168__[GeneID=105681168]","Bombyx_mandarina|XP_028034730.1_Fibh__[GeneID=114246424]","Bombyx_mori|NP_001106733.1_FIBH__[GeneID=693030]","Cimex_lectularius|XP_014255731.1_LOC106670162__[GeneID=106670162]","Cimex_lectularius|XP_014255735.1_LOC106670165__[GeneID=106670165]","Cimex_lectularius|XP_024084252.1_LOC106670148__[GeneID=106670148]","Cotesia_glomerata|XP_044597749.1_LOC123274246__[GeneID=123274246]","Cydia_amplana|XP_063365161.1_LOC134653699__[GeneID=134653699]","Galleria_mellonella|XP_026760882.2_LOC113519866__[GeneID=113519866]","Halyomorpha_halys|XP_066907948.1_LOC106679084__[GeneID=106679084]","Homalodisca_vitripennis|XP_046674477.1_LOC124363296__[GeneID=124363296]","Homalodisca_vitripennis|XP_046674982.1_LOC124363763__[GeneID=124363763]","Homalodisca_vitripennis|XP_046674983.1_LOC124363764__[GeneID=124363764]","Ischnura_elegans|XP_046382228.1_LOC124153170__[GeneID=124153170]","Ischnura_elegans|XP_046409266.1_LOC124174215__[GeneID=124174215]","Leptopilina_boulardi|XP_051157026.1_LOC127279011__[GeneID=127279011]_[isoform=X1]","Manduca_sexta|XP_037294123.1_LOC115449923__[GeneID=115449923]","Maniola_jurtina|XP_045777009.1_LOC123875302__[GeneID=123875302]","Monomorium_pharaonis|XP_012524667.2_LOC105830070__[GeneID=105830070]","Nilaparvata_lugens|XP_022186122.2_LOC111045123__[GeneID=111045123]","Nilaparvata_lugens|XP_022187670.2_LOC111046429__[GeneID=111046429]","Planococcus_citri|XP_065218367.1_LOC135844163__[GeneID=135844163]","Plutella_xylostella|XP_037963315.2_LOC105392941__[GeneID=105392941]_[isoform=X1]","Vanessa_cardui|XP_046971272.1_LOC124538299__[GeneID=124538299]_[isoform=X1]","Vespula_vulgaris|XP_050845642.1_LOC127062096__[GeneID=127062096]_[isoform=X1]"],"x":{"dtype":"f4","bdata":"ZAuKQGL0nUD\u002fQZ5ApdOdQOrwfUD9\u002f4pAl2mXQOfhq0ChQ5pAbyiSQA3BjkDlBaBAZCqYQLkahEAnCK1A9Qp+QBBsjkDW0KNAr3GdQCxCrUDFC6dAX9mJQO2VpEBykqpAqCaTQP6riECTV5FA"},"xaxis":"x","y":{"dtype":"f4","bdata":"8hJTQepZLUFzpAxBa4tDQa\u002fqU0GGqAhBM2YGQTFbCEF2UTNBnwgMQf6lTUG6ZARBQwUoQS+nP0E2vS9B78xMQXeXJUEgQU5BnV9VQcNeU0EKhz9B8bwvQVQoH0FZCihBppNYQW1DXEG5HjpB"},"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888888 ...

# %%
# Create DataFrame
embeddings_df = pd.DataFrame(embeddings_list)
embeddings_df['name'] = names_list

# Normalize embeddings for cosine UMAP
embeddings = embeddings_df.drop('name', axis=1).values
normalized_embeddings = normalize(embeddings, norm='l2')

# %%
# UMAP (2D + 3D) with cosine metric
umap_2d = UMAP(n_components=2, n_neighbors=40, min_dist=0.1, metric='cosine', random_state=42)
umap_coords_2d = umap_2d.fit_transform(normalized_embeddings)

umap_3d = UMAP(n_components=3, n_neighbors=40, min_dist=0.1, metric='cosine', random_state=42)
umap_coords_3d = umap_3d.fit_transform(normalized_embeddings)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:2462: UserWarning:
#
# n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:2462: UserWarning:
#
# n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1

# %%
# Create DataFrames from UMAP coordinates
umap_df_2d = pd.DataFrame(umap_coords_2d, columns=['UMAP_1', 'UMAP_2'])
umap_df_3d = pd.DataFrame(umap_coords_3d, columns=['UMAP_1', 'UMAP_2', 'UMAP_3'])

# Add original names
umap_df_2d['name'] = embeddings_df['name']
umap_df_3d['name'] = embeddings_df['name']

# Safe splitting functions
def extract_label(name):
    parts = name.split('|')
    return parts[0] if len(parts) > 0 else 'Unknown'

def extract_gene(name):
    parts = name.split('|')
    return parts[1] if len(parts) > 1 else 'Unknown'

# Apply safe split
umap_df_2d['label'] = umap_df_2d['name'].apply(extract_label)
umap_df_2d['Gene'] = umap_df_2d['name'].apply(extract_gene)
umap_df_3d['label'] = umap_df_3d['name'].apply(extract_label)
umap_df_3d['Gene'] = umap_df_3d['name'].apply(extract_gene)

# Clustering with HDBSCAN
clusterer = hdbscan.HDBSCAN(min_cluster_size=3, metric='euclidean')
clusters = clusterer.fit_predict(umap_coords_2d)
umap_df_2d['cluster'] = clusters.astype(str)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %%
from umap import UMAP
from sklearn.preprocessing import normalize
import pandas as pd
import plotly.express as px

# Normalize embeddings (for cosine similarity)
embeddings = embeddings_df.drop('name', axis=1).values
normalized_embeddings = normalize(embeddings, norm='l2')

# UMAP with tighter clusters
umap_2d = UMAP(
    n_components=2,
    n_neighbors=20,
    min_dist=0.01,
    metric='cosine',
    init='spectral',
    random_state=42
)
umap_coords_2d = umap_2d.fit_transform(normalized_embeddings)

# Build DataFrame
umap_df_2d = pd.DataFrame(umap_coords_2d, columns=['UMAP1', 'UMAP2'])
umap_df_2d['name'] = embeddings_df['name']

# Safe extract functions
def safe_extract_organism(x):
    parts = x.split('|')
    return parts[0] if len(parts) > 0 else 'Unknown'

def safe_extract_gene(x):
    parts = x.split('|')
    return parts[1] if len(parts) > 1 else 'Unknown'

# Apply safe parsing
umap_df_2d['Organism'] = umap_df_2d['name'].apply(safe_extract_organism)
umap_df_2d['Gene'] = umap_df_2d['name'].apply(safe_extract_gene)
umap_df_2d['Label'] = umap_df_2d['Organism'] + ' | ' + umap_df_2d['Gene']

# Interactive Plot with Plotly
fig = px.scatter(
    umap_df_2d,
    x='UMAP1',
    y='UMAP2',
    color='Label',
    hover_data=['Organism', 'Gene', 'name'],
    title='2D UMAP of Protein Embeddings (Interactive)',
    width=1000,
    height=600
)
fig.update_traces(marker=dict(size=8, line=dict(width=1, color='DarkSlateGrey')))
fig.update_layout(legend_title='Organism | Gene')
fig.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="7543e425-bcde-41a2-aae7-c46ecd7a463f" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7543e425-bcde-41a2-aae7-c46ecd7a463f")) {                    Plotly.newPlot(                        "7543e425-bcde-41a2-aae7-c46ecd7a463f",                        [{"customdata":[["2_Bombyx_mori","NP_001106733.1 FIBH  [GeneID=693030]","2_Bombyx_mori|NP_001106733.1 FIBH  [GeneID=693030]"]],"hovertemplate":"Label=2_Bombyx_mori | NP_001106733.1 FIBH  [GeneID=693030]\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2_Bombyx_mori | NP_001106733.1 FIBH  [GeneID=693030]","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"2_Bombyx_mori | NP_001106733.1 FIBH  [GeneID=693030]","orientation":"v","showlegend":true,"x":{"dtype":"f4","bdata":"NJ8xQQ=="},"xaxis":"x","y":{"dtype":"f4","bdata":"6vt4wA=="},"yaxis":"y","type":"scatter"},{"customdata":[["2_Cotesia_glomerata","XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]","2_Cotesia_glomerata|XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]"]],"hovertemplate":"Label=2_Cotesia_glomerata | XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2_Cotesia_glomerata | XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"2_Cotesia_glomerata | XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]","orientation":"v","showlegend":true,"x":{"dtype":"f4","bdata":"D7tPQQ=="},"xaxis":"x","y":{"dtype":"f4","bdata":"Iz+WwA=="},"yaxis":"y","type":"scatter"},{"customdata":[["2_Manduca_sexta","XP_037294123.1 FIBH  [GeneID=115449923]","2_Manduca_sexta|XP_037294123.1 FIBH  [GeneID=115449923]"]],"hovertemplate":"Label=2_Manduca_sexta | XP_037294123.1 FIBH  [GeneID=115449923]\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2_Manduca_sexta | XP_037294123.1 FIBH  [GeneID=115449923]","marker":{"color":"#00cc96","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"2_Manduca_sexta | XP_037294123.1 FIBH  [GeneID=115449923]","orientation":"v","showlegend":true,"x":{"dtype":"f4","bdata":"RsRFQQ=="},"xaxis":"x","y":{"dtype":"f4","bdata":"MXKKwA=="},"yaxis":"y","type":"scatter"},{"customdata":[["2_Planococcus_citri","XP_065218367.1 LOC135844163  [GeneID=135844163]","2_Planococcus_citri|XP_065218367.1 LOC135844163  [GeneID=135844163]"]],"hovertemplate":"Label=2_Planococcus_citri | XP_065218367.1 LOC135844163  [GeneID=135844163]\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2_Planococcus_citri | XP_065218367.1 LOC135844163  [GeneID=135844163]","marker":{"color":"#ab63fa","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"2_Planococcus_citri | XP_065218367.1 LOC135844163  [GeneID=135844163]","orientation":"v","showlegend":true,"x":{"dtype":"f4","bdata":"e5ViQQ=="},"xaxis":"x","y":{"dtype":"f4","bdata":"qMp2wA=="},"yaxis":"y","type":"scatt ...

# %%
from umap import UMAP
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
import pandas as pd
import plotly.express as px

# Normalize embeddings (for cosine similarity)
embeddings = embeddings_df.drop('name', axis=1).values
normalized_embeddings = normalize(embeddings, norm='l2')

# UMAP (2D)
umap_2d = UMAP(
    n_components=2,
    n_neighbors=20,
    min_dist=0.01,
    metric='cosine',
    init='spectral',
    random_state=42
)
umap_coords_2d = umap_2d.fit_transform(normalized_embeddings)

# Build DataFrame
umap_df_2d = pd.DataFrame(umap_coords_2d, columns=['UMAP1', 'UMAP2'])
umap_df_2d['name'] = embeddings_df['name']
umap_df_2d['Organism'] = umap_df_2d['name'].apply(lambda x: x.split('|')[0])
umap_df_2d['Gene'] = umap_df_2d['name'].apply(lambda x: x.split('|')[1])
umap_df_2d['Label'] = umap_df_2d['Organism'] + ' | ' + umap_df_2d['Gene']

# --- KMeans clustering ---
n_clusters = 3  # You can change this
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
umap_df_2d['Cluster'] = kmeans.fit_predict(umap_df_2d[['UMAP1', 'UMAP2']])

# --- Plot with clusters ---
fig = px.scatter(
    umap_df_2d,
    x='UMAP1',
    y='UMAP2',
    color=umap_df_2d['Cluster'].astype(str),  # Color by cluster ID
    hover_data=['Organism', 'Gene', 'name', 'Cluster'],
    title=f'2D UMAP + KMeans Clustering (k={n_clusters})',
    width=1200,
    height=800
)
fig.update_traces(marker=dict(size=8, line=dict(width=1, color='DarkSlateGrey')))
fig.update_layout(legend_title='Cluster ID')
fig.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="8de79034-8b18-4437-a9e4-fdee6362d303" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8de79034-8b18-4437-a9e4-fdee6362d303")) {                    Plotly.newPlot(                        "8de79034-8b18-4437-a9e4-fdee6362d303",                        [{"customdata":[["2_Bombyx_mori","NP_001106733.1 FIBH  [GeneID=693030]","2_Bombyx_mori|NP_001106733.1 FIBH  [GeneID=693030]",2],["2_Plutella_xylostella","XP_037963315.2 FIBH  [GeneID=105392941] [isoform=X1]","2_Plutella_xylostella|XP_037963315.2 FIBH  [GeneID=105392941] [isoform=X1]",2],["Achroia_grisella","XP_059058269.1 FIBH  [GeneID=131851741]","Achroia_grisella|XP_059058269.1 FIBH  [GeneID=131851741]",2],["Drosophila virilis","XP_015026081.2 LOC6633044 [GeneID=6633044] [isoform=X1]","Drosophila virilis|XP_015026081.2 LOC6633044 [GeneID=6633044] [isoform=X1]",2],["Galleria_mellonella","XP_026760882.2 FIBH  [GeneID=113519866]","Galleria_mellonella|XP_026760882.2 FIBH  [GeneID=113519866]",2],["Maniola_jurtina","XP_045777009.1 FIBH  [GeneID=123875302]","Maniola_jurtina|XP_045777009.1 FIBH  [GeneID=123875302]",2],["Vanessa_cardui","XP_046971272.1 FIBH  [GeneID=124538299] [isoform=X1]","Vanessa_cardui|XP_046971272.1 FIBH  [GeneID=124538299] [isoform=X1]",2]],"hovertemplate":"color=2\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cbr\u003eCluster=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"2","orientation":"v","showlegend":true,"x":{"dtype":"f4","bdata":"NJ8xQT7LO0H08zJBcztBQahSN0EDukdB1sU4QQ=="},"xaxis":"x","y":{"dtype":"f4","bdata":"6vt4wBR5fcCNj4zA8PFMwCvRY8DEG3fAKXGRwA=="},"yaxis":"y","type":"scatter"},{"customdata":[["2_Cotesia_glomerata","XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]","2_Cotesia_glomerata|XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]",1],["2_Manduca_sexta","XP_037294123.1 FIBH  [GeneID=115449923]","2_Manduca_sexta|XP_037294123.1 FIBH  [GeneID=115449923]",1],["Cydia amplana","XP_063357968.1 LOC134647545 [GeneID=134647545]","Cydia amplana|XP_063357968.1 LOC134647545 [GeneID=134647545]",1],["Homalodisca vitripennis","XP_046674982.1 LOC124363763 [GeneID=124363763]","Homalodisca vitripennis|XP_046674982.1 LOC124363763 [GeneID=124363763]",1],["Nilaparvata_lugens","XP_022186122.2 LOC111045123  [GeneID=111045123]","Nilaparvata_lugens|XP_022186122.2 LOC111045123  [GeneID=111045123]",1]],"hovertemplate":"color=1\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cbr\u003eCluster=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"1","orientation":"v","showlegend":true,"x":{"dtype":"f4","bdata":"D7tPQUbERUH+jz5BD9ZKQYZ+WUE="},"xaxis":"x","y":{"dtype":"f4","bdata":"Iz+WwDFyisADe5fAMPajwAlLm8A="},"yaxis":"y","type":"scatter"},{"customdata":[["2_Planococcus_citri","XP_065218367.1 LOC135844163  [GeneID=135844163]","2_Planococcus_citri|XP_065218367.1 LOC135844163  [GeneID=135844163]",0],["3_Homalodisca_vitripennis","XP_046674983.1 LOC124363764  [GeneID=124363764]","3_Homalodisca_vitripennis|XP_046674983.1 LOC124363764  [GeneID=124363764]",0],["Apis_mellifera","XP_006561846.2 LOC726750  [GeneID=726750] [isoform=X1]","Apis_mellifera|XP_006561846.2 LOC726750  [GeneID=726750] [isoform=X1]",0],["Bombus_impatiens","XP_012244504.1 LOC105681168  [GeneID= ...

# %%
from umap import UMAP
from sklearn.preprocessing import normalize
import pandas as pd
import plotly.express as px

# Normalize embeddings (for cosine similarity)
embeddings = embeddings_df.drop('name', axis=1).values
normalized_embeddings = normalize(embeddings, norm='l2')

# 3D UMAP
umap_3d = UMAP(
    n_components=3,
    n_neighbors=20,
    min_dist=0.01,
    metric='cosine',
    init='spectral',
    random_state=42
)
umap_coords_3d = umap_3d.fit_transform(normalized_embeddings)

# Build DataFrame
umap_df_3d = pd.DataFrame(umap_coords_3d, columns=['UMAP1', 'UMAP2', 'UMAP3'])
umap_df_3d['name'] = embeddings_df['name']
umap_df_3d['Organism'] = umap_df_3d['name'].apply(lambda x: x.split('|')[0])
umap_df_3d['Gene'] = umap_df_3d['name'].apply(lambda x: x.split('|')[1])
umap_df_3d['Label'] = umap_df_3d['Organism'] + ' | ' + umap_df_3d['Gene']

# 3D interactive plot with Plotly
fig = px.scatter_3d(
    umap_df_3d,
    x='UMAP1',
    y='UMAP2',
    z='UMAP3',
    color='Label',
    hover_data=['Organism', 'Gene', 'name'],
    title='3D UMAP of Protein Embeddings (Interactive)',
    width=1000,
    height=700
)
fig.update_traces(marker=dict(size=4, line=dict(width=0.5, color='DarkSlateGrey')))
fig.update_layout(legend_title='Organism | Gene')
fig.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="e7d20475-aa51-4fd5-abe4-7f3de2f98429" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e7d20475-aa51-4fd5-abe4-7f3de2f98429")) {                    Plotly.newPlot(                        "e7d20475-aa51-4fd5-abe4-7f3de2f98429",                        [{"customdata":[["2_Bombyx_mori","NP_001106733.1 FIBH  [GeneID=693030]","2_Bombyx_mori|NP_001106733.1 FIBH  [GeneID=693030]"]],"hovertemplate":"Label=2_Bombyx_mori | NP_001106733.1 FIBH  [GeneID=693030]\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eUMAP3=%{z}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2_Bombyx_mori | NP_001106733.1 FIBH  [GeneID=693030]","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":0.5},"size":4},"mode":"markers","name":"2_Bombyx_mori | NP_001106733.1 FIBH  [GeneID=693030]","scene":"scene","showlegend":true,"x":{"dtype":"f4","bdata":"wvyEQA=="},"y":{"dtype":"f4","bdata":"fMukQA=="},"z":{"dtype":"f4","bdata":"KzlZQQ=="},"type":"scatter3d"},{"customdata":[["2_Cotesia_glomerata","XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]","2_Cotesia_glomerata|XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]"]],"hovertemplate":"Label=2_Cotesia_glomerata | XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eUMAP3=%{z}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2_Cotesia_glomerata | XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"DarkSlateGrey","width":0.5},"size":4},"mode":"markers","name":"2_Cotesia_glomerata | XP_044580933.1 LOC123262670  [GeneID=123262670] [isoform=X1]","scene":"scene","showlegend":true,"x":{"dtype":"f4","bdata":"hYlkQA=="},"y":{"dtype":"f4","bdata":"HZGgQA=="},"z":{"dtype":"f4","bdata":"JF1EQQ=="},"type":"scatter3d"},{"customdata":[["2_Manduca_sexta","XP_037294123.1 FIBH  [GeneID=115449923]","2_Manduca_sexta|XP_037294123.1 FIBH  [GeneID=115449923]"]],"hovertemplate":"Label=2_Manduca_sexta | XP_037294123.1 FIBH  [GeneID=115449923]\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eUMAP3=%{z}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2_Manduca_sexta | XP_037294123.1 FIBH  [GeneID=115449923]","marker":{"color":"#00cc96","symbol":"circle","line":{"color":"DarkSlateGrey","width":0.5},"size":4},"mode":"markers","name":"2_Manduca_sexta | XP_037294123.1 FIBH  [GeneID=115449923]","scene":"scene","showlegend":true,"x":{"dtype":"f4","bdata":"Dgt7QA=="},"y":{"dtype":"f4","bdata":"TxexQA=="},"z":{"dtype":"f4","bdata":"ekxNQQ=="},"type":"scatter3d"},{"customdata":[["2_Planococcus_citri","XP_065218367.1 LOC135844163  [GeneID=135844163]","2_Planococcus_citri|XP_065218367.1 LOC135844163  [GeneID=135844163]"]],"hovertemplate":"Label=2_Planococcus_citri | XP_065218367.1 LOC135844163  [GeneID=135844163]\u003cbr\u003eUMAP1=%{x}\u003cbr\u003eUMAP2=%{y}\u003cbr\u003eUMAP3=%{z}\u003cbr\u003eOrganism=%{customdata[0]}\u003cbr\u003eGene=%{customdata[1]}\u003cbr\u003ename=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2_Planococcus_citri | XP_065218367.1 LOC135844163  [GeneID=135844163]","marker":{"color":"#ab63fa","symbol":"circle","line":{"color":"DarkSlateGrey","width":0.5},"size":4},"mode":"markers","name":"2_Planococcus_citri | XP_065218367.1 LOC135844163  [GeneID=135844163]","sc ...

# %%
fig_3d = px.scatter_3d(
    umap_df_3d,
    x='UMAP_1',
    y='UMAP_2',
    z='UMAP_3',
    color='label',         # Organism = color
    symbol='Gene',         # Gene = shape
    hover_data=['name', 'label', 'Gene'],
    title='3D UMAP of Protein Embeddings (WIDE View)'
)

# Make markers larger and add borders
fig_3d.update_traces(marker=dict(size=5, line=dict(width=1, color='black')))

# Wider, larger 3D plot
fig_3d.update_layout(
    width=1200,
    height=800,
    legend_title_text='Organism',
    margin=dict(l=0, r=0, b=0, t=40),
    title_x=0.5,
    scene=dict(
        xaxis=dict(showticklabels=False, title=''),
        yaxis=dict(showticklabels=False, title=''),
        zaxis=dict(showticklabels=False, title=''),
        camera=dict(
            eye=dict(x=1.2, y=2.2, z=0.8)  # Adjust camera for a nice angled view
        )
    )
)

fig_3d.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="0da33492-074d-4f31-b9cd-367cb49ff58d" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0da33492-074d-4f31-b9cd-367cb49ff58d")) {                    Plotly.newPlot(                        "0da33492-074d-4f31-b9cd-367cb49ff58d",                        [{"customdata":[["Achroia_grisella|XP_059058269.1 LOC131851741  [GeneID=131851741]","Achroia_grisella","XP_059058269.1 LOC131851741  [GeneID=131851741]"]],"hovertemplate":"label=%{customdata[1]}\u003cbr\u003eGene=%{customdata[2]}\u003cbr\u003eUMAP_1=%{x}\u003cbr\u003eUMAP_2=%{y}\u003cbr\u003eUMAP_3=%{z}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Achroia_grisella, XP_059058269.1 LOC131851741  [GeneID=131851741]","marker":{"color":"#636efa","symbol":"circle","line":{"color":"black","width":1},"size":5},"mode":"markers","name":"Achroia_grisella, XP_059058269.1 LOC131851741  [GeneID=131851741]","scene":"scene","showlegend":true,"x":{"dtype":"f4","bdata":"uf6MPw=="},"y":{"dtype":"f4","bdata":"l1dQvw=="},"z":{"dtype":"f4","bdata":"sR12QQ=="},"type":"scatter3d"},{"customdata":[["Apis_mellifera|XP_006561846.2 LOC726750  [GeneID=726750] [isoform=X1]","Apis_mellifera","XP_006561846.2 LOC726750  [GeneID=726750] [isoform=X1]"]],"hovertemplate":"label=%{customdata[1]}\u003cbr\u003eGene=%{customdata[2]}\u003cbr\u003eUMAP_1=%{x}\u003cbr\u003eUMAP_2=%{y}\u003cbr\u003eUMAP_3=%{z}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apis_mellifera, XP_006561846.2 LOC726750  [GeneID=726750] [isoform=X1]","marker":{"color":"#EF553B","symbol":"diamond","line":{"color":"black","width":1},"size":5},"mode":"markers","name":"Apis_mellifera, XP_006561846.2 LOC726750  [GeneID=726750] [isoform=X1]","scene":"scene","showlegend":true,"x":{"dtype":"f4","bdata":"vUURQA=="},"y":{"dtype":"f4","bdata":"1bl1vQ=="},"z":{"dtype":"f4","bdata":"FttaQQ=="},"type":"scatter3d"},{"customdata":[["Bombus_impatiens|XP_012244504.1 LOC105681168  [GeneID=105681168]","Bombus_impatiens","XP_012244504.1 LOC105681168  [GeneID=105681168]"]],"hovertemplate":"label=%{customdata[1]}\u003cbr\u003eGene=%{customdata[2]}\u003cbr\u003eUMAP_1=%{x}\u003cbr\u003eUMAP_2=%{y}\u003cbr\u003eUMAP_3=%{z}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bombus_impatiens, XP_012244504.1 LOC105681168  [GeneID=105681168]","marker":{"color":"#00cc96","symbol":"square","line":{"color":"black","width":1},"size":5},"mode":"markers","name":"Bombus_impatiens, XP_012244504.1 LOC105681168  [GeneID=105681168]","scene":"scene","showlegend":true,"x":{"dtype":"f4","bdata":"k\u002fgXQA=="},"y":{"dtype":"f4","bdata":"6GslPQ=="},"z":{"dtype":"f4","bdata":"ePY\u002fQQ=="},"type":"scatter3d"},{"customdata":[["Bombyx_mandarina|XP_028034730.1 Fibh  [GeneID=114246424]","Bombyx_mandarina","XP_028034730.1 Fibh  [GeneID=114246424]"]],"hovertemplate":"label=%{customdata[1]}\u003cbr\u003eGene=%{customdata[2]}\u003cbr\u003eUMAP_1=%{x}\u003cbr\u003eUMAP_2=%{y}\u003cbr\u003eUMAP_3=%{z}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bombyx_mandarina, XP_028034730.1 Fibh  [GeneID=114246424]","marker":{"color":"#ab63fa","symbol":"x","line":{"color":"black","width":1},"size":5},"mode":"markers","name":"Bombyx_mandarina, XP_028034730.1 Fibh  [GeneID=114246424]","scene":"scene","showlegend":true,"x":{"dtype":"f4","bdata":"QgAeQA=="},"y":{"dtype":"f4","bdata":"gD8GvQ=="},"z":{"dtype":"f4","bdata":"I55uQQ=="},"type":"scatter3d"},{"customdata":[["Bombyx_mori|NP_001106733.1 FIBH  [GeneID=693030]","Bombyx_mori","NP_001106733.1 FIBH  [GeneID=693030]"]],"hovertemplate":"label=%{customdata[1]}\u003cbr\u003eGene=%{customdata[2]}\u003cbr\u003eUMA ...
